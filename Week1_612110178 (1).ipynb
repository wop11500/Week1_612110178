# %%
course = {
      "954340": "Enterprise Database",
      "954471": "Business Data Mining",
      "954472": "Business Data Visualization",
      "954499": "Independent Study"
}
print (course.values())
# Out:
# <built-in method values of dict object at 0x7f427c4ca320>

# %%
L = [[1,2,3],
     [4,5,6],
     [7,8,9]]
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
L.sort(reverse=True)
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %%
my_string = "Hello World"
my_string.split()
# Out:
# ['Hello', 'World']

# %%
a = input("What is your A = ")
b = input("What is your B = ")
# Out:
# What is your A = 20
# What is your B = 30

# %%
c = (int(a) + int(b))
print(c)
# Out:
# 50

# %%
pi = 3.14
print("The pi is equal to " + str(pi))
# Out:
# The pi is equal to 3.14

# %%
age = input("")
tenyears_age = int(age) + 10
print(tenyears_age)
# Out:
# 20
# 30

# %%
L = [[1,2,3],
     [4,5,6],
     [7,8,9]]
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
L.sort()
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
L.reverse()
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %%
L.sort()
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
L = [1,2,3,"Hello","World"]
L
# Out:
# [1, 2, 3, 'Hello', 'World']

# %%
L.append ("Pasachon")
L
# Out:
# [1, 2, 3, 'Hello', 'World', 3, 'Pasachon']

# %%
L.remove(3)
L
# Out:
# [1, 2, 'Hello', 'World', 3, 'Pasachon']

# %%
L.pop(4)
L
# Out:
# [1, 2, 'Hello', 'World', 'Pasachon']

# %%
L.pop(3)
L
# Out:
# [1, 2, 'Hello', 'Pasachon']

# %%
L.pop(0)
L
# Out:
# [2, 'Hello', 'Pasachon']

# %%
my_string = "Hello World"
my_string.find("World")
# Out:
# 6

# %%
a = input("What is your A = ")
b = input("What is your B = ")
# Out:
# What is your A = 20
# What is your B = 30

# %%
c = (int(a)+int(b))
print(c)
# Out:
# 50

# %%
print ("Hello my name is %s my age is %.2f" % (name,age))
# Out:
# Hello my name is Pasachon my age is 20.00

# %%
print ("Hello my name is "+name+" my age is "+str(age))
# Out:
# Hello my name is Pasachon my age is 20

# %%
name = "Pasachon"
age = 20
msg = f"Hello my name is {name} and my age is {age}"
print(msg)
# Out:
# Hello my name is Pasachon and my age is 20

# %%
greeting = "Pasachon"
name = ' Chaimongkol'
print(greeting + name)
# Out:
# Pasachon Chaimongkol

# %% [raw]
# a = input("What is your A = ")
# b = input("What is your B = ")

# %%
c = b + a 
print(c)
# Out:
# 3020

# %%
c = a + b
print(c )
# Out:
# 2030

# %%
2
# Out:
# 2

# %%
7+9 - (4*2)+(4*3)
# Out:
# 20

# %%
8 // 2
# Out:
# 4

# %%
pi = 3.14
print(pi)
# Out:
# 3.14

# %%
goal = "fight for money !!"
print(goal)
# Out:
# fight for money !!

# %%
age = 25 
print(age)
# Out:
# 25

# %%
country = input("where are you from = ")
# Out:
# where are you from = chiang mai

# %%
print ("I am"+age+" !!")
# Out:
# I am20 !!

# %%
age = input ("what is your age = ")
# Out:
# what is your age = 20

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
name = "pangpond"
print ("Pasachon"+name+" !")
# Out:
# Pasachonpangpond !

# %%
print ("Pasachon")
# Out:
# Pasachon

# %% [markdown]
# print ("Csgo")

# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3
# description

# %%
# Title
